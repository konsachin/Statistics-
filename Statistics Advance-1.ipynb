# %% [raw]
#                      Statistics Advance-1

# %% [raw]
# Q1. What is the Probability density function?
#
# The Probability Density Function (PDF) is a fundamental concept in probability theory and statistics, particularly in the context of continuous random variables. It defines the probability distribution of a continuous random variable, specifying the likelihood of observing different values within a given range.
#
# The PDF represents the relative likelihood of a continuous random variable taking on specific values within its possible range. Unlike the Probability Mass Function (PMF) used for discrete random variables, which assigns probabilities to individual values, the PDF assigns probabilities to intervals or ranges of values.
#
# Mathematically, the PDF is typically denoted by
# 𝑓
# (
# 𝑥
# )
# f(x), where
# 𝑥
# x represents the random variable. It satisfies the following properties:
#
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# f(x)≥0 for all
# 𝑥
# x (non-negativity)
# The total area under the curve of the PDF over the entire range of possible values is equal to 1. This represents the total probability of all possible outcomes.
# The probability of a random variable falling within a specific interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is given by the area under the PDF curve between
# 𝑎
# a and
# 𝑏
# b.
# The PDF can take various forms depending on the distribution of the random variable. Some common examples of continuous probability distributions with PDFs include the normal distribution, exponential distribution, uniform distribution, and many others.
#
# In summary, the Probability Density Function provides a mathematical description of the probability distribution of a continuous random variable, specifying the likelihood of observing different values within a given range.

# %% [raw]
# Q2. What are the types of Probability distribution?
# Probability distributions categorize random variables into different types based on the nature of their outcomes and the distribution of probabilities associated with those outcomes. The two main types of probability distributions are:
#
# Discrete Probability Distributions:
# Discrete probability distributions are associated with discrete random variables, which have a countable number of distinct outcomes.
# The Probability Mass Function (PMF) is used to describe the probabilities associated with each possible outcome of a discrete random variable.
# Examples of discrete probability distributions include:
# Bernoulli distribution
# Binomial distribution
# Poisson distribution
# Geometric distribution
# Continuous Probability Distributions:
# Continuous probability distributions are associated with continuous random variables, which can take any value within a specified range.
# The Probability Density Function (PDF) is used to describe the relative likelihood of a continuous random variable taking on specific values within its range.
# Examples of continuous probability distributions include:
# Normal (Gaussian) distribution
# Exponential distribution
# Uniform distribution
# Chi-square distribution
# Student's t-distribution
# These are the two main types of probability distributions, but there are many specific distributions within each category, each with its own characteristics and applications. Understanding the properties and characteristics of different probability distributions is essential for various fields such as statistics, machine learning, finance, and many others.

# %% [raw]
# Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.
#
# import numpy as np
# import math
#
# def normal_pdf(x, mu, sigma):
#     """
#     Calculate the probability density function (PDF) of a normal distribution
#     at a given point x, with mean mu and standard deviation sigma.
#
#     Parameters:
#         x (float): The point at which to evaluate the PDF.
#         mu (float): The mean of the normal distribution.
#         sigma (float): The standard deviation of the normal distribution.
#
#     Returns:
#         float: The value of the PDF at the given point x.
#     """
#     exponent = -((x - mu) ** 2) / (2 * sigma ** 2)
#     pdf = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(exponent)
#     return pdf
#
# # Example usage:
# mean = 0
# std_dev = 1
# x_value = 1
# pdf_value = normal_pdf(x_value, mean, std_dev)
# print("PDF at x =", x_value, ":", pdf_value)

# %% [markdown]
# Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
# distribution can be applied.
#
# The Binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, where each trial has only two possible outcomes: success or failure. The properties of the Binomial distribution include:
#
# Fixed number of trials: The number of trials, denoted by
# 𝑛
# n, is fixed in advance.
# Independent trials: Each trial is independent of the others.
# Two outcomes: Each trial has only two possible outcomes: success or failure.
# Constant probability of success: The probability of success, denoted by
# 𝑝
# p, remains constant for each trial.
# Discrete values: The Binomial distribution is defined for discrete random variables, representing the number of successes, which can take on integer values from 0 to
# 𝑛
# n.
# Two examples of events where the Binomial distribution can be applied include:
#
# Coin flipping: Consider flipping a fair coin
# 𝑛
# n times. Each flip has two possible outcomes: heads (success) or tails (failure). The number of heads obtained in
# 𝑛
# n flips follows a Binomial distribution with parameters
# 𝑛
# n (number of trials) and
# 𝑝
# =
# 0.5
# p=0.5 (probability of success).
# Drug trials: In clinical drug trials, patients are often randomly assigned to receive either the drug being tested or a placebo. The outcome of each patient's treatment can be classified as either a success (e.g., the drug is effective) or a failure (e.g., the drug is not effective). The number of patients who respond positively to the drug out of a fixed number of patients
# 𝑛
# n follows a Binomial distribution with parameters
# 𝑛
# n (number of trials) and
# 𝑝
# p (probability of success), where
# 𝑝
# p represents the proportion of patients who respond positively to the drug in the population.

# %% [raw]
# Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
# and plot a histogram of the results using matplotlib.
#
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate a random sample of size 1000 from a binomial distribution
# sample_size = 1000
# probability_of_success = 0.4
# random_sample = np.random.binomial(n=1, p=probability_of_success, size=sample_size)
#
# # Plot a histogram of the results
# plt.hist(random_sample, bins=2, color='skyblue', edgecolor='black', alpha=0.7)
# plt.title('Histogram of Random Sample from Binomial Distribution')
# plt.xlabel('Outcome (0: Failure, 1: Success)')
# plt.ylabel('Frequency')
# plt.xticks([0, 1], ['Failure', 'Success'])
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.show()

# %% [raw]
# Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution
# with given mean at a given point.
#
# import math
#
# def poisson_cdf(k, lam):
#     """
#     Calculate the cumulative distribution function (CDF) of a Poisson distribution
#     at a given point k, with mean lambda (λ).
#
#     Parameters:
#         k (int): The point at which to evaluate the CDF.
#         lam (float): The mean of the Poisson distribution.
#
#     Returns:
#         float: The value of the CDF at the given point k.
#     """
#     cdf = 0
#     for i in range(k + 1):
#         cdf += math.exp(-lam) * (lam ** i) / math.factorial(i)
#     return cdf
#
# # Example usage:
# mean = 3
# point = 2
# cdf_value = poisson_cdf(point, mean)
# print("CDF at k =", point, ":", cdf_value)

# %% [raw]
# Q7. How Binomial distribution different from Poisson distribution?
#
# The Binomial distribution and Poisson distribution are both used to model the number of successes in a series of independent Bernoulli trials, but they are suited for different scenarios and have distinct characteristics:
#
# Nature of Events:
# Binomial distribution: The Binomial distribution is used when there are a fixed number of independent trials, each with two possible outcomes: success or failure. The number of trials, denoted by
# 𝑛
# n, is fixed in advance.
# Poisson distribution: The Poisson distribution is used when the number of events occurring in a fixed interval of time or space is of interest, and the events occur independently of each other. The number of events in the interval is not fixed in advance.
# Number of Trials:
# Binomial distribution: In a Binomial distribution, the number of trials, denoted by
# 𝑛
# n, is fixed and known in advance.
# Poisson distribution: In a Poisson distribution, there is no fixed number of trials. Instead, the distribution models the number of events occurring in a fixed interval of time or space.
# Parameters:
# Binomial distribution: The Binomial distribution is characterized by two parameters: the number of trials
# 𝑛
# n and the probability of success
# 𝑝
# p on each trial.
# Poisson distribution: The Poisson distribution is characterized by a single parameter
# 𝜆
# λ, which represents the average rate of events occurring in the interval. The mean and variance of a Poisson distribution are both equal to
# 𝜆
# λ.
# Shape:
# Binomial distribution: The shape of a Binomial distribution is symmetric if
# 𝑝
# =
# 0.5
# p=0.5, and it becomes increasingly skewed as
# 𝑝
# p moves away from 0.5.
# Poisson distribution: The shape of a Poisson distribution is typically right-skewed, with a long tail on the right side.
# Approximation:
# Binomial distribution: A Poisson distribution can be used as an approximation to a Binomial distribution when the number of trials
# 𝑛
# n is large and the probability of success
# 𝑝
# p is small, such that
# 𝑛
# 𝑝
# np is moderate.
# Poisson distribution: A Binomial distribution can be used as an approximation to a Poisson distribution when the number of trials
# 𝑛
# n is large and the probability of success
# 𝑝
# p is small, such that
# 𝑛
# 𝑝
# np is moderate.

# %% [raw]
# Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the
# sample mean and variance.
#
# import numpy as np
#
# # Generate a random sample of size 1000 from a Poisson distribution with mean 5
# sample_size = 1000
# mean = 5
# random_sample = np.random.poisson(lam=mean, size=sample_size)
#
# # Calculate the sample mean and variance
# sample_mean = np.mean(random_sample)
# sample_variance = np.var(random_sample)
#
# print("Sample Mean:", sample_mean)
# print("Sample Variance:", sample_variance)

# %% [raw]
# Q9. How mean and variance are related in Binomial distribution and Poisson distribution?
#
# In both the Binomial distribution and Poisson distribution, the mean (
# 𝜇
# μ) and variance (
# 𝜎
# 2
# σ
# 2
#  ) are related, but their specific relationships differ due to the different characteristics of these distributions:
#
# Binomial Distribution:
# Mean (
# 𝜇
# μ): For a Binomial distribution, the mean (
# 𝜇
# μ) is equal to the product of the number of trials (
# 𝑛
# n) and the probability of success on each trial (
# 𝑝
# p):
# 𝜇
# =
# 𝑛
# 𝑝
# μ=np.
# Variance (
# 𝜎
# 2
# σ
# 2
#  ): The variance (
# 𝜎
# 2
# σ
# 2
#  ) of a Binomial distribution is equal to the product of the number of trials (
# 𝑛
# n), the probability of success on each trial (
# 𝑝
# p), and the probability of failure on each trial (
# 1
# −
# 𝑝
# 1−p):
# 𝜎
# 2
# =
# 𝑛
# 𝑝
# (
# 1
# −
# 𝑝
# )
# σ
# 2
#  =np(1−p).
# Therefore, in a Binomial distribution, the variance is directly proportional to the mean and also depends on the probability of success and failure.
# Poisson Distribution:
# Mean (
# 𝜇
# μ): For a Poisson distribution, the mean (
# 𝜇
# μ) is equal to the parameter
# 𝜆
# λ, which represents the average rate of events occurring in the interval.
# Variance (
# 𝜎
# 2
# σ
# 2
#  ): The variance (
# 𝜎
# 2
# σ
# 2
#  ) of a Poisson distribution is also equal to the parameter
# 𝜆
# λ:
# 𝜎
# 2
# =
# 𝜆
# σ
# 2
#  =λ.
# Therefore, in a Poisson distribution, the variance is equal to the mean.
# In summary:
#
# In a Binomial distribution, the variance is proportional to the mean and depends on the number of trials (
# 𝑛
# n) and the probability of success (
# 𝑝
# p).
# In a Poisson distribution, the variance is equal to the mean and depends solely on the parameter
# 𝜆
# λ, which represents the average rate of events occurring in the interval.

# %% [markdown]
# Q10. In normal distribution with respect to mean position, where does the least frequent data appear?
#
#
# In a normal distribution, also known as a Gaussian distribution, the least frequent data points appear farthest away from the mean, towards the tails of the distribution.
#
# Since the normal distribution is symmetric around its mean, with the mean being the highest point of the distribution, the least frequent data points occur in the tails of the distribution, which are the regions farthest away from the mean on both sides.
#
# Specifically, the least frequent data points are found in the tails of the distribution beyond a certain number of standard deviations from the mean. In a standard normal distribution (with a mean of 0 and a standard deviation of 1), the least frequent data points are found in the tails beyond ±2 or ±3 standard deviations from the mean.
#
# In summary, in a normal distribution, the least frequent data points appear in the tails of the distribution, farthest away from the mean on both sides.
