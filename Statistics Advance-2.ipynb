# %% [raw]
#        Statistics Advance-2

# %% [raw]
# Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with
# an example.
#
# The Probability Mass Function (PMF) and Probability Density Function (PDF) are both mathematical functions used in probability theory and statistics to describe the probabilities associated with the outcomes of a random variable. However, they are used for different types of random variables: the PMF is used for discrete random variables, while the PDF is used for continuous random variables.
#
# Probability Mass Function (PMF):
# The PMF is a function that gives the probability that a discrete random variable takes on a specific value.
# It maps each possible value of the discrete random variable to its probability.
# The PMF satisfies two properties: non-negativity (the probability associated with each value is non-negative) and summing to 1 (the sum of probabilities for all possible values is equal to 1).
# Mathematically, the PMF is denoted as
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x), where
# 𝑋
# X is the random variable and
# 𝑥
# x is a specific value.
# Example: Consider rolling a fair six-sided die. The PMF of the random variable representing the outcome of a single roll would assign a probability of
# 1
# 6
# 6
# 1
# ​
#   to each possible outcome (1, 2, 3, 4, 5, or 6).
# Probability Density Function (PDF):
# The PDF is a function that describes the relative likelihood of a continuous random variable taking on a specific value within a range.
# It does not directly give probabilities but rather gives the density of probabilities at each point in the range.
# The area under the PDF curve over a range represents the probability of the random variable falling within that range.
# The PDF satisfies two properties: non-negativity (the density of probabilities at each point is non-negative) and integrating to 1 (the integral of the PDF over the entire range is equal to 1).
# Mathematically, the PDF is denoted as
# 𝑓
# (
# 𝑥
# )
# f(x), where
# 𝑥
# x is a specific value of the continuous random variable.
# Example: Consider the standard normal distribution. The PDF of the random variable representing standard normally distributed values is given by the bell-shaped curve described by the formula
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 2
# 𝜋
# 𝑒
# −
# 𝑥
# 2
# 2
# f(x)=
# 2π
# ​
#
# 1
# ​
#  e
# −
# 2
# x
# 2
#
# ​
#
#  .
# In summary, the PMF and PDF are mathematical functions used to describe the probabilities associated with the outcomes of random variables. The PMF is used for discrete random variables, while the PDF is used for continuous random variables.

# %% [raw]
# Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?
#
# The Cumulative Distribution Function (CDF) is a function used in probability theory and statistics to describe the probability that a random variable
# 𝑋
# X takes on a value less than or equal to a specified point
# 𝑥
# x. In other words, it gives the cumulative probability up to a certain value of the random variable.
#
# Mathematically, the CDF of a random variable
# 𝑋
# X, denoted as
# 𝐹
# (
# 𝑥
# )
# F(x), is defined as:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)
#
# The CDF satisfies several properties:
#
# Non-decreasing:
# 𝐹
# (
# 𝑥
# )
# F(x) increases or remains constant as
# 𝑥
# x increases.
# Bounded:
# 0
# ≤
# 𝐹
# (
# 𝑥
# )
# ≤
# 1
# 0≤F(x)≤1, for all
# 𝑥
# x.
# Right-continuous:
# 𝐹
# (
# 𝑥
# )
# F(x) is continuous from the right; it does not have jumps at any point.
# The CDF provides information about the distribution of a random variable and is useful for various purposes, including:
#
# Probability Calculation: It allows us to calculate the probability that a random variable falls within a certain range by subtracting the CDF values at the endpoints of the range.
# Quantile Calculation: It helps in finding quantiles, such as the median, quartiles, and percentiles, of a distribution.
# Model Evaluation: It enables the comparison of different probability distributions and the assessment of goodness-of-fit for statistical models.
# Example:
# Consider a standard six-sided fair die. The CDF of the random variable representing the outcome of a single roll of the die can be calculated as follows:
#
# Let
# 𝑋
# X be the random variable representing the outcome of a single roll of the die.
# The possible values of
# 𝑋
# X are integers from 1 to 6.
# The CDF
# 𝐹
# (
# 𝑥
# )
# F(x) for
# 𝑥
# =
# 1
# x=1 is the probability that the outcome is less than or equal to 1, which is
# 1
# 6
# 6
# 1
# ​
#  .
# Similarly,
# 𝐹
# (
# 𝑥
# )
# F(x) for
# 𝑥
# =
# 2
# x=2 is
# 2
# 6
# =
# 1
# 3
# 6
# 2
# ​
#  =
# 3
# 1
# ​
#  , for
# 𝑥
# =
# 3
# x=3 is
# 3
# 6
# =
# 1
# 2
# 6
# 3
# ​
#  =
# 2
# 1
# ​
#  , and so on.
# The CDF increases in a step-wise manner until it reaches 1 when
# 𝑥
# =
# 6
# x=6, indicating that the probability of the outcome being less than or equal to 6 is 1.

# %% [raw]
# Q3: What are some examples of situations where the normal distribution might be used as a model?
# Explain how the parameters of the normal distribution relate to the shape of the distribution.
#
# The normal distribution, also known as the Gaussian distribution, is one of the most widely used probability distributions in statistics and various fields of science. It is used to model a wide range of phenomena in which the data tend to cluster around a central value with symmetric tails on either side. Some examples of situations where the normal distribution might be used as a model include:
#
# Height of individuals: The heights of individuals in a population often follow a normal distribution, with most people clustering around the average height and fewer people at the extreme ends of the distribution.
# Test scores: Test scores, such as those on standardized tests like the SAT or IQ tests, often approximate a normal distribution, with most people scoring around the mean score and fewer people scoring very low or very high.
# Measurement errors: Errors in measurement or observation, such as errors in laboratory measurements or reading errors in scientific experiments, often follow a normal distribution.
# Natural phenomena: Many natural phenomena, such as the distribution of rainfall, wind speeds, or temperatures, can be reasonably modeled using a normal distribution.
# The normal distribution is characterized by two parameters: the mean (
# 𝜇
# μ) and the standard deviation (
# 𝜎
# σ). These parameters play crucial roles in determining the shape of the distribution:
#
# Mean (
# 𝜇
# μ): The mean determines the location of the center of the distribution. It represents the average or expected value of the data. The normal distribution is symmetric around the mean, so the mean is also the point of maximum probability density. Shifting the mean to the right or left will shift the entire distribution along the horizontal axis.
# Standard deviation (
# 𝜎
# σ): The standard deviation measures the spread or dispersion of the data points around the mean. A larger standard deviation indicates that the data points are more spread out from the mean, resulting in a wider and flatter distribution. Conversely, a smaller standard deviation indicates that the data points are more clustered around the mean, resulting in a narrower and taller distribution.
# In summary, the parameters of the normal distribution, the mean (
# 𝜇
# μ) and the standard deviation (
# 𝜎
# σ), determine the location and spread of the distribution, respectively. Adjusting these parameters can alter the shape of the distribution, making the normal distribution a versatile tool for modeling various real-world phenomena.

# %% [raw]
# Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal
# Distribution.
#
# The normal distribution, also known as the Gaussian distribution, holds significant importance in various fields due to its many desirable properties. Some of the key reasons for the importance of the normal distribution are:
#
# Central Limit Theorem: The normal distribution arises naturally as the limiting distribution of the sample mean of a large number of independent and identically distributed random variables, regardless of the underlying distribution of the variables. This makes it a fundamental concept in statistical inference and hypothesis testing.
# Versatility: The normal distribution is incredibly versatile and can model a wide variety of natural phenomena. Many real-world processes exhibit behavior that can be reasonably approximated by a normal distribution, making it a valuable tool for modeling and analysis.
# Ease of Use: The normal distribution has simple mathematical properties, such as symmetry and a well-defined shape determined by the mean and standard deviation. This simplicity makes it easy to work with and interpret in statistical analyses.
# Statistical Inference: Many statistical methods and techniques, such as confidence intervals, hypothesis testing, and regression analysis, rely on assumptions of normality. The normal distribution often serves as a convenient and reliable approximation for the distribution of sample statistics in these methods.
# Risk Management and Finance: In finance and risk management, the normal distribution is commonly used to model asset returns, stock prices, interest rates, and other financial variables. It plays a crucial role in portfolio theory, option pricing, and risk assessment.
# Real-life examples of phenomena that can be modeled using the normal distribution include:
#
# Height of Individuals: The heights of individuals in a population often follow a normal distribution, with most people clustering around the average height and fewer people at the extreme ends of the distribution.
# Test Scores: Test scores, such as those on standardized tests like the SAT or IQ tests, often approximate a normal distribution, with most people scoring around the mean score and fewer people scoring very low or very high.
# Measurement Errors: Errors in measurement or observation, such as errors in laboratory measurements or reading errors in scientific experiments, often follow a normal distribution.
# Natural Phenomena: Many natural phenomena, such as the distribution of rainfall, wind speeds, or temperatures, can be reasonably modeled using a normal distribution.
# Overall, the normal distribution's importance lies in its wide applicability, simplicity, and usefulness in modeling and analyzing various real-world phenomena and statistical processes.

# %% [raw]
# Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli
# Distribution and Binomial Distribution?
#
# The Bernoulli distribution is a discrete probability distribution that represents the outcome of a single Bernoulli trial, which has two possible outcomes: success (usually denoted as 1) or failure (usually denoted as 0). The distribution is named after Swiss mathematician Jacob Bernoulli, who introduced it in the early 18th century.
#
# The probability mass function (PMF) of the Bernoulli distribution is defined as:
#
# p & \text{if } x = 1 \\
# 1 - p & \text{if } x = 0
# \end{cases} \]
# where:
# - \( p \) is the probability of success (i.e., the probability that \( X = 1 \)).
# - \( 1 - p \) is the probability of failure (i.e., the probability that \( X = 0 \)).
# The Bernoulli distribution is a special case of the binomial distribution with only one trial (\( n = 1 \)).
# Example:
# Consider flipping a fair coin. If we define success as getting heads and failure as getting tails, then the outcome of a single coin flip can be modeled using a Bernoulli distribution. Let \( X \) be the random variable representing the outcome of the coin flip. The probability of getting heads (success) is \( p = 0.5 \), and the probability of getting tails (failure) is \( 1 - p = 0.5 \). Therefore, the Bernoulli distribution for this scenario is:
# \[ P(X = x) = \begin{cases}
# 0.5 & \text{if } x = 1 \text{ (heads)} \\
# 0.5 & \text{if } x = 0 \text{ (tails)}
# \end{cases} \]
# The difference between the Bernoulli distribution and the binomial distribution lies in the number of trials:
# 1. **Bernoulli Distribution**:
# - Represents the outcome of a single Bernoulli trial (i.e., one trial with two possible outcomes: success or failure).
# - It has only one parameter: the probability of success (\( p \)).
# 2. **Binomial Distribution**:
# - Represents the number of successes in a fixed number of independent Bernoulli trials (i.e., multiple trials, each with two possible outcomes: success or failure).
# - It has two parameters: the number of trials (\( n \)) and the probability of success on each trial (\( p \)).
# In summary, while the Bernoulli distribution models the outcome of a single trial, the binomial distribution models the number of successes in multiple independent trials. The binomial distribution is a generalization of the Bernoulli distribution.

# %% [raw]
# To find the probability that a randomly selected observation from a normally distributed dataset with a mean of 50 and a standard deviation of 10 will be greater than 60, we can use the standard normal distribution and the z-score formula. The z-score measures how many standard deviations an observation is from the mean.
#
# The formula to calculate the z-score is:
#
# 𝑧
# =
# 𝑥
# −
# 𝜇
# 𝜎
# z=
# σ
# x−μ
# ​
#
#
# where:
#
# 𝑥
# x is the value of the observation (60 in this case),
# 𝜇
# μ is the mean of the distribution (50),
# 𝜎
# σ is the standard deviation of the distribution (10).
# Substituting the given values into the formula, we get:
#
# 𝑧
# =
# 60
# −
# 50
# 10
# =
# 10
# 10
# =
# 1
# z=
# 10
# 60−50
# ​
#  =
# 10
# 10
# ​
#  =1
#
# Now, we need to find the probability that a randomly selected observation will be greater than 60. Since we are dealing with a standard normal distribution, we can look up this probability directly from the standard normal distribution table (or use a calculator or software).
#
# From the standard normal distribution table, the probability of a z-score greater than 1 (which corresponds to the probability of an observation being greater than 60) is approximately 0.1587.
#
# Therefore, the probability that a randomly selected observation from the dataset will be greater than 60 is approximately 0.1587 or 15.87%.

# %% [raw]
# Q7: Explain uniform Distribution with an example.
#
# The uniform distribution is a probability distribution that describes a situation where all outcomes within a given range are equally likely to occur. In other words, each possible outcome has the same probability of occurring.
#
# Mathematically, the probability density function (PDF) of a continuous uniform distribution is defined as:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# f(x)=
# b−a
# 1
# ​
#
#
# where:
#
# 𝑎
# a is the minimum value of the range,
# 𝑏
# b is the maximum value of the range,
# 𝑓
# (
# 𝑥
# )
# f(x) is the probability density function.
# The cumulative distribution function (CDF) of the continuous uniform distribution is a straight line that increases linearly from 0 to 1 over the range from
# 𝑎
# a to
# 𝑏
# b.
#
# Example:
# Consider a scenario where you roll a fair six-sided die. The outcome of each roll can be modeled using a discrete uniform distribution, where each of the six possible outcomes (1, 2, 3, 4, 5, 6) has an equal probability of
# 1
# 6
# 6
# 1
# ​
#  . This means that each number on the die has the same chance of appearing, regardless of the previous outcomes.
#
# In this example, the minimum value
# 𝑎
# a is 1 (the smallest possible outcome of rolling the die), and the maximum value
# 𝑏
# b is 6 (the largest possible outcome of rolling the die). Therefore, the probability density function (PDF) of the uniform distribution for this scenario is:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 6
# −
# 1
# =
# 1
# 5
# f(x)=
# 6−1
# 1
# ​
#  =
# 5
# 1
# ​
#
#
# This means that the probability of rolling any specific number on the die is
# 1
# 5
# 5
# 1
# ​
#  , which is consistent with the fact that each outcome is equally likely.
#
# In summary, the uniform distribution is characterized by a constant probability of each outcome within a given range. It is commonly encountered in situations where there is no bias towards any particular outcome, such as rolling dice, selecting random numbers, or sampling from a continuous range with equal probability.

# %% [raw]
# Q8: What is the z score? State the importance of the z score.
#
# The z-score, also known as the standard score or z-value, is a measure of how many standard deviations a particular data point is from the mean of a distribution. It quantifies the deviation of an individual data point from the mean in terms of the standard deviation of the distribution.
#
# Mathematically, the z-score of a data point
# 𝑥
# x in a distribution with mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ is calculated using the formula:
#
# 𝑧
# =
# 𝑥
# −
# 𝜇
# 𝜎
# z=
# σ
# x−μ
# ​
#
#
# where:
#
# 𝑥
# x is the value of the data point,
# 𝜇
# μ is the mean of the distribution,
# 𝜎
# σ is the standard deviation of the distribution,
# 𝑧
# z is the z-score.
# The z-score indicates the position of the data point relative to the mean of the distribution. A positive z-score indicates that the data point is above the mean, while a negative z-score indicates that the data point is below the mean. The magnitude of the z-score indicates how far the data point is from the mean in terms of standard deviations.
#
# Importance of the z-score:
#
# Standardization: The z-score standardizes data by transforming it into a common scale with a mean of 0 and a standard deviation of 1. This allows for comparisons between data points from different distributions.
# Identification of Outliers: Z-scores can be used to identify outliers in a dataset. Data points with z-scores that fall far from the mean (typically beyond ±2 or ±3 standard deviations) may be considered outliers.
# Probability Calculations: Z-scores are used to calculate probabilities and percentiles in the standard normal distribution. They help determine the probability of observing a data point within a certain range of values.
# Statistical Inference: Z-scores play a crucial role in hypothesis testing, confidence interval estimation, and other statistical inference techniques. They help assess the significance of observed differences or effects.
# Data Analysis and Interpretation: Z-scores provide a standardized way to interpret data and compare individual observations to the overall distribution. They help identify data points that are unusual or noteworthy relative to the rest of the dataset.
# Overall, the z-score is a valuable statistical tool that facilitates data analysis, interpretation, and inference by quantifying the position of data points relative to the mean of a distribution in terms of standard deviations.

# %% [raw]
# Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.
#
# The Central Limit Theorem (CLT) is a fundamental theorem in probability theory and statistics that states that the sampling distribution of the sample mean of a random variable approaches a normal distribution as the sample size increases, regardless of the shape of the population distribution. In simpler terms, it asserts that if we take repeated samples of a population and calculate the mean of each sample, the distribution of those sample means will be approximately normal, even if the original population distribution is not normal.
#
# Formally, the Central Limit Theorem can be stated as follows:
#
# Let
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# .
# .
# .
# ,
# 𝑋
# 𝑛
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,...,X
# n
# ​
#   be a sequence of independent and identically distributed random variables with a finite mean
# 𝜇
# μ and finite variance
# 𝜎
# 2
# σ
# 2
#  . Then, as
# 𝑛
# n approaches infinity, the distribution of the sample mean
# 𝑋
# ˉ
# X
# ˉ
#   approaches a normal distribution with mean
# 𝜇
# μ and variance
# 𝜎
# 2
# 𝑛
# n
# σ
# 2
#
# ​
#  :
#
# 𝑋
# ˉ
# ∼
# 𝑁
# (
# 𝜇
# ,
# 𝜎
# 2
# 𝑛
# )
# X
# ˉ
#  ∼N(μ,
# n
# σ
# 2
#
# ​
#  )
#
# where:
#
# 𝑋
# ˉ
# X
# ˉ
#   is the sample mean,
# 𝜇
# μ is the population mean,
# 𝜎
# 2
# σ
# 2
#   is the population variance,
# 𝑛
# n is the sample size.
# Significance of the Central Limit Theorem:
#
# Sampling Distribution: The Central Limit Theorem provides insight into the behavior of sample means and other sample statistics. It explains why the sample mean tends to be normally distributed, making it a key concept in statistical inference.
# Statistical Inference: The CLT is the basis for many statistical methods and techniques, such as confidence intervals and hypothesis testing. It allows statisticians to make inferences about population parameters based on sample statistics.
# Population Approximation: The CLT allows researchers to approximate the distribution of a population based on the distribution of sample means. This is particularly useful when the population distribution is unknown or difficult to characterize.
# Generalizability: The CLT applies to a wide range of distributions, regardless of their shape or form. This makes it a powerful and versatile tool in statistics.
# Robustness: Even if the underlying population distribution is not normal, the distribution of sample means will approach a normal distribution as the sample size increases. This robustness makes the CLT applicable in various real-world scenarios.
# Overall, the Central Limit Theorem is a fundamental concept in statistics with widespread applications in research, data analysis, and decision-making. It provides a theoretical foundation for understanding the behavior of sample statistics and enables statistical inference in a wide range of contexts.
